# %% [markdown]
# ### Cab-Driver Agent
#
#                                                                                     - Rajagopal Shenoy G
#                                                                                     - Anindya Sudhir

# %%
# Importing libraries
import numpy as np
import random
import math
import time
from collections import deque
import collections
import pickle

# for building DQN model
from keras import layers
from keras import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

# for plotting graphs
import matplotlib.pyplot as plt

# Import the environment
from Env import CabDriver
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Defining Time Matrix
#
# - Let us try to understand the Time Matrix

# %%
# Loading the time matrix provided
Time_matrix = np.load("TM.npy")
print('Shape of Time Matrix:', Time_matrix.shape)

# Get the maximum time taken for a ride available in Time Matrix
print('Maximum time taken for a ride:', Time_matrix.max())

# Get the minimum time taken for a ride available in Time Matrix
print('Minimum time taken for a ride:', Time_matrix.min())
# Out:
# Shape of Time Matrix: (5, 5, 24, 7)
# Maximum time taken for a ride: 11.0
# Minimum time taken for a ride: 0.0

# %% [markdown]
# ## WHAT TO DO WITH THE OBSERVATION BELOW?
# Two things are possible:
# - Do nothing: Just ignore this
# - This means ride took less than an hour. So increment the ride time (or pickup time) by one hour for the next ride in the step function in env.py file

# %%
# Interestingly, there are some rides which have taken 0 hours. Let us check them
count_zero = 0
for p in range(Time_matrix.shape[0]):
    for q in range(Time_matrix.shape[1]):
        for hour in range(Time_matrix.shape[2]):
            for day in range(Time_matrix.shape[3]):
                # Get the rides with 0 ride time where start and end locations are not same
                if (Time_matrix[p][q][hour][day] == 0) and (p != q):
                    print(p+1, q+1, hour, day)
                    count_zero += 1
print('Total counts with ride times as 0 between two locations:', count_zero)
# Out:
# 1 2 0 5
# 1 2 1 5
# 1 2 2 5
# 1 2 3 5
# 1 2 4 5
# 1 2 5 5
# 1 4 12 6
# 1 4 13 6
# 1 4 14 6
# 1 4 15 6
# 1 4 16 6
# 1 4 17 6
# 1 4 18 0
# 1 4 19 0
# 1 4 20 0
# 1 4 21 0
# 1 4 22 0
# 1 4 23 0
# 1 5 0 3
# 1 5 1 3
# 1 5 2 3
# 1 5 3 3
# 1 5 4 3
# 1 5 5 3
# 1 5 6 4
# 1 5 6 5
# 1 5 7 4
# 1 5 7 5
# 1 5 8 4
# 1 5 8 5
# 1 5 9 4
# 1 5 9 5
# 1 5 10 4
# 1 5 10 5
# 1 5 11 4
# 1 5 11 5
# 1 5 12 3
# 1 5 12 5
# 1 5 13 3
# 1 5 13 5
# 1 5 14 3
# 1 5 14 5
# 1 5 15 3
# 1 5 15 5
# 1 5 16 3
# 1 5 16 5
# 1 5 17 3
# 1 5 17 5
# 2 1 0 5
# 2 1 1 5
# 2 1 2 5
# 2 1 3 5
# 2 1 4 5
# 2 1 5 5
# 2 4 12 6
# 2 4 13 6
# 2 4 14 6
# 2 4 15 6
# 2 4 16 6
# 2 4 17 6
# 2 4 18 6
# 2 4 19 6
# 2 4 20 6
# 2 4 21 6
# 2 4 22 6
# 2 4 23 6
# 2 5 12 0
# 2 5 12 1
# 2 5 12 2
# 2 5 12 3
# 2 5 12 5
# 2 5 13 0
# 2 5 13 1
# 2 5 13 2
# 2 5 13 3
# 2 5 13 5
# 2 5 14 0
# 2 5 14 1
# 2 5 14 2
# 2 5 14 3
# 2 5 14 5
# 2 5 15 0
# 2 5 15 1
# 2 5 15 2
# 2 5 15 3
# 2 5 15 5
# 2 5 16 0
# 2 5 16 1
# 2 5 16 2
# 2 5 16 3
# 2 5 16 5
# 2 5 17 0
# 2 5 17 1
# 2 5 17 2
# 2 5 17 3
# 2 5 17 5
# 2 5 18 1
# 2 5 18 3
# 2 5 18 4
# 2 5 19 1
# 2 5 19 3
# 2 5 19 4
# 2 5 20 1
# 2 5 20 3
# 2 5 20 4
# 2 5 21 1
# 2 5 21 3
# 2 5 21 4
# 2 5 22 1
# 2 5 22 3
# 2 5 22 4
# 2 5 23 1
# 2 5 23 3
# 2 5 23 4
# 3 4 18 3
# 3 4 19 3
# 3 4 20 3
# 3 4 21 3
# 3 4 22 3
# 3 4 23 3
# 3 5 0 1
# 3 5 0 5
# 3 5 1 1
# 3 5 1 5
# 3 5 2 1
# 3 5 2 5
# 3 5 3 1
# 3 5 3 5
# 3 5 4 1
# 3 5 4 5
# 3 5 5 1
# 3 5 5 5
# 3 5 12 5
# 3 5 12 6
# 3 5 13 5
# 3 5 13 6
# 3 5 14 5
# 3 5 14 6
# 3 5 15 5
# 3 5 15 6
# 3 5 16 5
# 3 5 16 6
# 3 5 17 5
# 3 5 17 6
# 3 5 18 0
# 3 5 18 3
# 3 5 18 4
# 3 5 18 5
# 3 5 19 0
# 3 5 19 3
# 3 5 19 4
# 3 5 19 5
# 3 5 20 0
# 3 5 20 3
# 3 5 20 4
# 3 5 20 5
# 3 5 21 0
# 3 5 21 3
# 3 5 21 4
# 3 5 21 5
# 3 5 22 0
# 3 5 22 3
# 3 5 22 4
# 3 5 22 5
# 3 5 23 0
# 3 5 23 3
# 3 5 23 4
# 3 5 23 5
# 4 1 12 6
# 4 1 13 6
# 4 1 14 6
# 4 1 15 6
# 4 1 16 6
# 4 1 17 6
# 4 1 18 0
# 4 1 19 0
# 4 1 20 0
# 4 1 21 0
# 4 1 22 0
# 4 1 23 0
# 4 2 12 6
# 4 2 13 6
# 4 2 14 6
# 4 2 15 6
# 4 2 16 6
# 4 2 17 6
# 4 2 18 6
# 4 2 19 6
# 4 2 20 6
# 4 2 21 6
# 4 2 22 6
# 4 2 23 6
# 4 3 18 3
# 4 3 19 3
# 4 3 20 3
# 4 3 21 3
# 4 3 22 3
# 4 3 23 3
# 5 1 0 3
# 5 1 1 3
# 5 1 2 3
# 5 1 3 3
# 5 1 4 3
# 5 1 5 3
# 5 1 6 4
# 5 1 6 5
# 5 1 7 4
# 5 1 7 5
# 5 1 8 4
# 5 1 8 5
# 5 1 9 4
# 5 1 9 5
# 5 1 10 4
# 5 1 10 5
# 5 1 11 4
# 5 1 11 5
# 5 1 12 3
# 5 1 12 5
# 5 1 13 3
# 5 1 13 5
# 5 1 14 3
# 5 1 14 5
# 5 1 15 3
# 5 1 15 5
# 5 1 16 3
# 5 1 16 5
# 5 1 17 3
# 5 1 17 5
# 5 2 12 0
# 5 2 12 1
# 5 2 12 2
# 5 2 12 3
# 5 2 12 5
# 5 2 13 0
# 5 2 13 1
# 5 2 13 2
# 5 2 13 3
# 5 2 13 5
# 5 2 14 0
# 5 2 14 1
# 5 2 14 2
# 5 2 14 3
# 5 2 14 5
# 5 2 15 0
# 5 2 15 1
# 5 2 15 2
# 5 2 15 3
# 5 2 15 5
# 5 2 16 0
# 5 2 16 1
# 5 2 16 2
# 5 2 16 3
# 5 2 16 5
# 5 2 17 0
# 5 2 17 1
# 5 2 17 2
# 5 2 17 3
# 5 2 17 5
# 5 2 18 1
# 5 2 18 3
# 5 2 18 4
# 5 2 19 1
# 5 2 19 3
# 5 2 19 4
# 5 2 20 1
# 5 2 20 3
# 5 2 20 4
# 5 2 21 1
# 5 2 21 3
# 5 2 21 4
# 5 2 22 1
# 5 2 22 3
# 5 2 22 4
# 5 2 23 1
# 5 2 23 3
# 5 2 23 4
# 5 3 0 1
# 5 3 0 5
# 5 3 1 1
# 5 3 1 5
# 5 3 2 1
# 5 3 2 5
# 5 3 3 1
# 5 3 3 5
# 5 3 4 1
# 5 3 4 5
# 5 3 5 1
# 5 3 5 5
# 5 3 12 5
# 5 3 12 6
# 5 3 13 5
# 5 3 13 6
# 5 3 14 5
# 5 3 14 6
# 5 3 15 5
# 5 3 15 6
# 5 3 16 5
# 5 3 16 6
# 5 3 17 5
# 5 3 17 6
# 5 3 18 0
# 5 3 18 3
# 5 3 18 4
# 5 3 18 5
# 5 3 19 0
# 5 3 19 3
# 5 3 19 4
# 5 3 19 5
# 5 3 20 0
# 5 3 20 3
# 5 3 20 4
# 5 3 20 5
# 5 3 21 0
# 5 3 21 3
# 5 3 21 4
# 5 3 21 5
# 5 3 22 0
# 5 3 22 3
# 5 3 22 4
# 5 3 22 5
# 5 3 23 0
# 5 3 23 3
# 5 3 23 4
# 5 3 23 5
# Total counts with ride times as 0 between two locations: 324

# %% [markdown]
# #### Tracking the state-action pairs for checking convergence

# %%
# Initialise Q_dictionary as 'Q_dict' and States_tracked as 'States_track' (for convergence)
Q_dict = collections.defaultdict(dict)
states_tracked = collections.defaultdict(dict)

# %%
# Initialise states to be tracked
def initialise_tracking_states():
    # Initialize some 6 Q-values which need to be tracked for checking convergence
    sample_q_values = [((2,17,6), (4,5)), ((4,22,5),(2,5)), ((2,4,1),(0,0)), 
                        ((1,18,3),(4,2)), ((3,12,6),(1,4)), ((4,6,2),(4,3))]                      
    for q_values in sample_q_values:
        state = q_values[0]
        action = q_values[1]
        states_tracked[state][action] = []

# %%
def save_tracking_states():
    for state in states_tracked.keys():
        for action in states_tracked[state].keys():
            if state in Q_dict and action in Q_dict[state]:
                states_tracked[state][action].append(Q_dict[state][action])

# %%
# Defining a function which will return valid (all possible actions) actions corresponding to a state
# Important to avoid errors during deployment.

def valid_actions(state):
    # All possible actions from the current state are taken
    valid_actions = [i for i in env.action_space if i[0] == state[0]]   
    valid_actions.append((0,0))
    return valid_actions

# %%
# Defining a function which will add new Q-values to the Q-dictionary. 
def add_to_dict(state):
    #valid_act = valid_actions(state)
    if state not in Q_dict.keys():
        for action in env.action_space: #valid_act:
            Q_dict[state][action] = 0

# %%
#Defining a function to save the Q-dictionary as a pickle file
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
initialise_tracking_states()

# %% [markdown]
# ### Agent Class
#
# If you are using this framework, you need to fill the following to complete the following code block:
# 1. State and Action Size
# 2. Hyperparameters
# 3. Create a neural-network model in function 'build_model()'
# 4. Define epsilon-greedy strategy in function 'get_action()'
# 5. Complete the function 'append_sample()'. This function appends the recent experience tuple <state, action, reward, new-state> to the memory
# 6. Complete the 'train_model()' function with following logic:
#    - If the memory size is greater than mini-batch size, you randomly sample experiences from memory as per the mini-batch size and do the following:
#       - Initialise your input and output batch for training the model
#       - Calculate the target Q value for each sample: reward + gamma*max(Q(s'a,))
#       - Get Q(s', a) values from the last trained model
#       - Update the input batch as your encoded state-action and output batch as your Q-values
#       - Then fit your DQN model using the updated input and output batch.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        # Define size of state and action
        self.state_size = state_size
        self.action_size = action_size
        
        # The Cab Driver Environment
        self.env = CabDriver()

        # Write here: Specify your hyper parameters for the DQN
        # After several trial and error (not shown in code), following values are chosen
        self.discount_factor = 0.95
        self.learning_rate = 0.01      
        self.epsilon_max = 1.0
        self.epsilon_decay = 0.005 #0.0001
        self.epsilon_min = 0.0
        self.batch_size = 32        
        
        # Create replay memory using deque
        self.memory = deque(maxlen=2000)

        # Create main model and target model
        self.model = self.build_model()
        self.target_model = self.build_model()

        # Initialize the target model
        self.update_target_model()

    # Approximate Q function using Neural Network as per Architecture 1
    def build_model(self):
        model = Sequential()
        
        # Hidden layers
        model.add(Dense(32, input_dim = self.state_size, activation = 'relu', kernel_initializer = 'he_uniform'))
        model.add(Dense(32, activation = 'relu', kernel_initializer = 'he_uniform'))
        model.add(Dense(1, activation = 'linear', kernel_initializer = 'he_uniform'))
        
        model.compile(loss = 'mse', optimizer = Adam(lr = self.learning_rate))
        model.summary
        return model

    # After some time intervals, update the target model to be same with model
    def update_target_model(self):
        '''
        Update the target Q-value network to current Q-value network after training for a episode. This means that weights an
        biases of target Q-value network will become same as current Q-value network.
        '''
        self.target_model.set_weights(self.model.get_weights())
        
    # Get action from model using epsilon-greedy policy
    def get_action(self, state, time):
        # Write your code here:
        # get action from model using epsilon-greedy policy
        # Decay in ε after we generate each sample from the environment 
        
        epsilon = self.epsilon_min + (self.epsilon_max - self.epsilon_min) * np.exp(-self.epsilon_decay*time)
        
        if np.random.rand() <= epsilon:
            # Exploration: choose a random action from all possible actions
            actions = self.env.requests(state)
            action = random.choice(actions)
        else:
            # Exploitation: choose the action with the highest q(s, a)
            actions = self.env.requests(state)
            input_nn = np.zeros((len(actions), self.state_size))
            i=0
            for request_action in actions:
                input_nn[i] = self.env.state_encod_arch2(state, request_action)
                i+=1
                #encoded_state = self.env.state_encod_arch2(state, request_action)
                #q_value[request_action]= self.model.predict(encoded_state)[0]
            q_value = self.model.predict(input_nn)
            action = actions[np.argmax(q_value)]
            
        
        return action  

    # Calculate the Q value
    def calc_q(self, state, action):
        # Q-value is calculated from the NN model by sending the state as one hot encoded input
        state_onehot = self.env.state_encod_arch2(state, action)
        q_value = self.model.predict(state_onehot)
        
        return q_value[0]
    
    # Save sample <s,a,r,s'> to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        # Write your code here:
        # save sample <s,a,r,s'> to the replay memory
        self.memory.append((state, action, reward, next_state, done))

    # pick samples randomly from replay memory (with batch_size) and train the network
    def train_model(self):
        """
        Train the neural network over a minibatch. Input to the network is the states,
        output is the target q-value corresponding to each action.
        """
        
        if len(self.memory) >= self.batch_size:
            # Sample batch from the memory
            mini_batch = random.sample(self.memory, self.batch_size)
            update_input = np.zeros((self.batch_size, self.state_size))
            action, reward, done = [], [], []
            target_q_value = []
            # Set the values of input, action, reward, target and done using memory
            for i in range(self.batch_size):
                update_input[i] = self.env.state_encod_arch2(mini_batch[i][0], mini_batch[i][1])
                action.append(mini_batch[i][1])
                reward.append(mini_batch[i][2])
                done.append(mini_batch[i][4])
                all_actions = self.env.action_space
                input_per_batch_nn = np.zeros((len(all_actions), self.state_size))
                action_idx=0
                for request_action in all_actions:
                    input_per_batch_nn[action_idx] = self.env.state_encod_arch2(mini_batch[i][3], request_action)
                    action_idx+=1
                q_value = self.target_model.predict(input_per_batch_nn)
                target_q_value.append(np.amax(q_value))

            # 1. Predict the target from earlier model
            target = self.model.predict(update_input)
                
                
            #2. Update your 'update_output' and 'update_input' batch. Be careful to use the encoded state-action pair
            for i in range(self.batch_size):
                if done[i]:
                    target[i] = reward[i]
                else:
                    target[i] = reward[i] + self.discount_factor * (target_q_value[i])
                    #print('amax' + str(np.amax(target_val[i])))

            # 4. Fit your model and track the loss values
            self.model.fit(update_input, target, batch_size = self.batch_size, epochs = 1, verbose = 0)

    def save(self, name):
        self.model.save_weights(name)

# %% [markdown]
# ### DQN block

# %%
# Keep a track of total rewards and steps per episode
total_rewards = []
total_steps = []

# %%
# Call the environment
env = CabDriver()

# %%
def trainer(episodes):
    
    start_time = time.time()
    # Call the DQN agent
    agent = DQNAgent(env.state_size_arch2, env.action_size)    
    initialise_tracking_states()
        
    for episode in range(episodes):

        # Call all the initialised variables of the environment
        terminal_state = False
        state = env.reset()
               
        # Rewards counter
        rewards = 0
        
        # Number of steps taken by agent
        agent_steps = 0
    
        while not terminal_state:     
            # Write your code here
            
            add_to_dict(state) # Update the dictionary with the current state
            
            # Get action for the current state and go one step in environment
            # 1. Pick epsilon-greedy action from possible actions for the current state
            action = agent.get_action(state, episode)
            
            # 2. Evaluate your reward and next state
            reward, next_state, terminal_state = env.step(state, action, Time_matrix)
            
            # Save the sample <s, a, r, s'> to the replay memory
            # 3. Append the experience to the memory
            agent.append_sample(state, action, reward, next_state, terminal_state)
            
            # Every time step do the training
            # 4. Train the model by calling function agent.train_model
            agent.train_model()

            # 5a. Keep a track of rewards, Q-values, loss
            # Tracking the Q-values for selected state-action pairs
            Q_dict[state][action] += agent.calc_q(state, action)

            # Update the count of number of steps taken by agent and the rewards
            agent_steps += 1
            rewards += reward

            # Go to next state
            state = next_state
            
        # Update the NN model weights
        agent.update_target_model()
            
        # 5b. Keep a track of rewards, Q-values, loss
        # Update total awards and steps per episode
        total_steps.append(agent_steps)
        total_rewards.append(rewards)
        
        # Save the model weights periodically
        #if episode % 100 == 0:
        #    agent.save('nnmodel.hd5')
         
        # Tracking the Q-Values
        #if (episode == 1999):         # at the 1999th episode
         #   initialise_tracking_states()  
        if ((episode + 1) % 2000) == 0:   # every 2000th episode
            save_tracking_states()
           # save_obj(states_tracked,'States_tracked')
            
        print('Progress: '+ str(round(episode/episodes*100,2)) + '%',  end='\r')        
    # Final Progress Report
    elapsed_time = time.time() - start_time
    print('\033[1m' + 'Final Progress Report:' + '\033[0m')
    print('Total execution time:                              {:.2f} seconds'.format(elapsed_time))
    print('Total number of rides :                           ', sum(total_steps))
    print('Average rides taken by the driver per 30 days:    ', round(sum(total_steps) / episodes, 2))
    print('Total rewards :                                   ', sum(total_rewards))
    print('Average rewards earned by the driver per 30 days: ', round(sum(total_rewards) / episodes, 2))
        
    # Save the tracked states and Policy
    save_obj(states_tracked,'States_tracked')
    save_obj(Q_dict,'Policy')
    agent.save('nnmodel.hd5')

# %%
# Train for ten episodes and see if it works
trainer(1000)
# Out:
# Final Progress Report:
# Total execution time:                              4016.45 seconds
# Total number of rides :                            155980
# Average rides taken by the driver per 30 days:     155.98
# Total rewards :                                    808408
# Average rewards earned by the driver per 30 days:  808.41

# %% [markdown]
# ### Run the model

# %%
# Let us run the model for 50000 episodes and track the values
#trainer(50000)h

# %% [markdown]
# #### Check the Q-dictionary

# %%
print(Q_dict)
# Out:
# defaultdict(dict,
#             {(2, 3, 6): {(1, 2): array([1119.101], dtype=float32),
#               (1, 3): array([2172.9336], dtype=float32),
#               (1, 4): array([523.5663], dtype=float32),
#               (1, 5): array([510.37344], dtype=float32),
#               (2, 1): array([6149.5806], dtype=float32),
#               (2, 3): array([10672.591], dtype=float32),
#               (2, 4): array([2161.6128], dtype=float32),
#               (2, 5): array([1103.2168], dtype=float32),
#               (3, 1): array([463.46494], dtype=float32),
#               (3, 2): array([907.8778], dtype=float32),
#               (3, 4): array([1591.6368], dtype=float32),
#               (3, 5): 0,
#               (4, 1): array([1104.0808], dtype=float32),
#               (4, 2): array([686.5976], dtype=float32),
#               (4, 3): array([469.43173], dtype=float32),
#               (4, 5): array([2974.344], dtype=float32),
#               (5, 1): array([2441.118], dtype=float32),
#               (5, 2): array([1415.6154], dtype=float32),
#               (5, 3): array([3687.307], dtype=float32),
#               (5, 4): array([920.36255], dtype=float32),
#               (0, 0): array([3069.8032], dtype=float32)},
#              (3, 13, 6): {(1, 2): array([4002.2766], dtype=float32),
#               (1, 3): array([3791.2625], dtype=float32),
#               (1, 4): array([3833.6213], dtype=float32),
#               (1, 5): array([4197.696], dtype=float32),
#               (2, 1): array([7598.6733], dtype=float32),
#               (2, 3): array([3780.7974], dtype=float32),
#               (2, 4): array([1443.0789], dtype=float32),
#               (2, 5): array([493.20984], dtype=float32),
#               (3, 1): array([12118.298], dtype=float32),
#               (3, 2): array([13376.763], dtype=float32),
#               (3, 4): array([12669.272], dtype=float32),
#               (3, 5): array([7143.1997], dtype=float32),
#               (4, 1): array([1860.0546], dtype=float32),
#               (4, 2): array([949.6604], dtype=float32),
#               (4, 3): array([436.75812], dtype=float32),
#               (4, 5): array([1427.5421], dtype=float32),
#               (5, 1): array([6662.72], dtype=float32),
#               (5, 2): array([3847.1802], dtype=float32),
#               (5, 3): array([1344.2305], dtype=float32),
#               (5, 4): array([13139.315], dtype=float32),
#               (0, 0): array([32941.234], dtype=float32)},
#              (3, 14, 6): {(1, 2): array([3367.5698], dtype=float32),
#               (1, 3): array([1570.2206], dtype=float32),
#               (1, 4): array([4347.0396], dtype=float32),
#               (1, 5): array([3080.4153], dtype=float32),
#               (2, 1): array([4560.9355], dtype=float32),
#               (2, 3): array([3457.3992], dtype=float32),
#               (2, 4): array([1750.089], dtype=float32),
#               (2, 5): array([1616.292], dtype=float32),
#               (3, 1): array([11489.716], dtype=float32),
#               (3, 2): array([9217.41], dtype=float32),
#               (3, 4): array([14119.108], dtype=float32),
#               (3, 5): array([5381.9116], dtype=float32),
#               (4, 1): array([3348.1614], dtype=float32),
#               (4, 2): array([2565.66], dtype=float32),
#               (4, 3): array([2061.9175], dtype=float32),
#               (4, 5): array([1444.172], dtype=float32),
#               (5, 1): array([5504.254], dtype=float32),
#               (5, 2): array([2409.5833], dtype=float32),
#               (5, 3): array([985.4015], dtype=float32),
#               (5, 4): array([5834.74], dtype=float32),
#               (0, 0): array([44841.656], dtype=float32)},
#              (2, 19, 6): {(1, 2): array([967.03906], dtype=float32),
#               (1, 3): array([1027.4438], dtype=float32),
#               (1, 4): array([1054.827], dtype=float32),
#               (1, 5): array([994.12256], dtype=float32),
#               (2, 1): array([10585.605], dtype=float32),
#               (2, 3): array([27894.883], dtype=float32),
#               (2, 4): array([2956.061], dtype=float32),
#               (2, 5): array([12030.445], dtype=float32),
#               (3, 1): array([4093.7148], dtype=float32),
#               (3, 2): array([1609.8903], dtype=float32),
#               (3, 4): array([1332.7163], dtype=float32),
#               (3, 5): array([1197.6779], dtype=float32),
#               (4, 1): array([2021.188], dtype=float32),
#               (4, 2): array([2651.532], dtype=float32),
#               (4, 3): array([5157.357], dtype=float32),
#               (4, 5): array([7972.0215], dtype=float32),
#               (5, 1): array([2513.1006], dtype=float32),
#               (5, 2): array([1260.7849], dtype=float32),
#               (5, 3): array([3228.1394], dtype=float32),
#               (5, 4): array([2108.9902], dtype=float32),
#               (0, 0): array([2564.397], dtype=float32)},
#              (2, 23, 6): {(1, 2): 0,
#               (1, 3): 0,
#               (1, 4): array([546.6098], dtype=float32),
#               (1, 5): array([1002.05457], dtype=float32),
#               (2, 1): array([3528.576], dtype=float32),
#               (2, 3): array([14881.888], dtype=float32),
#               (2, 4): array([2961.1624], dtype=float32),
#               (2, 5): array([2163.467], dtype=float32),
#               (3, 1): array([980.56024], dtype=float32),
#               (3, 2): array([585.2158], dtype=float32),
#               (3, 4): 0,
#               (3, 5): 0,
#               (4, 1): array([1435.0956], dtype=float32),
#               (4, 2): array([3416.4077], dtype=float32),
#               (4, 3): array([2927.9373], dtype=float32),
#               (4, 5): array([695.2216], dtype=float32),
#               (5, 1): array([1898.2349], dtype=float32),
#               (5, 2): array([368.153], dtype=float32),
#               (5, 3): array([997.0021], dtype=float32),
#               (5, 4): array([471.55432], dtype=float32),
#               (0, 0): array([958.78394], dtype=float32)},
#              (5, 2, 6): {(1, 2): array([2494.5288], dtype=float32),
#               (1, 3): array([3507.4038], dtype=float32),
#               (1, 4): array([1103.0295], dtype=float32),
#               (1, 5): array([521.1045], dtype=float32),
#               (2, 1): array([1426.2446], dtype=float32),
#               (2, 3): array([2812.8667], dtype=float32),
#               (2, 4): array([318.21112], dtype=float32),
#               (2, 5): array([539.6382], dtype=float32),
#               (3, 1): array([978.9107], dtype=float32),
#               (3, 2): array([4658.5557], dtype=float32),
#               (3, 4): array([1974.4653], dtype=float32),
#               (3, 5): array([862.29614], dtype=float32),
#               (4, 1): array([522.1937], dtype=float32),
#               (4, 2): array([490.12662], dtype=float32),
#               (4, 3): array([863.2833], dtype=float32),
#               (4, 5): array([2038.0757], dtype=float32),
#               (5, 1): array([4221.7446], dtype=float32),
#               (5, 2): array([6346.054], dtype=float32),
#               (5, 3): array([4913.765], dtype=float32),
#               (5, 4): array([6321.0884], dtype=float32),
#               (0, 0): array([2774.8137], dtype=float32)},
#              (5, 3, 6): {(1, 2): array([2534.9338], dtype=float32),
#               (1, 3): array([5327.425], dtype=float32),
#               (1, 4): array([5324.0156], dtype=float32),
#               (1, 5): array([3173.7515], dtype=float32),
#               (2, 1): array([2750.467], dtype=float32),
#               (2, 3): array([4056.4075], dtype=float32),
#               (2, 4): array([1527.455], dtype=float32),
#               (2, 5): array([986.2403], dtype=float32),
#               (3, 1): array([1828.5471], dtype=float32),
#               (3, 2): array([6098.9565], dtype=float32),
#               (3, 4): array([3433.1108], dtype=float32),
#               (3, 5): array([4003.1243], dtype=float32),
#               (4, 1): array([931.9463], dtype=float32),
#               (4, 2): array([1528.0406], dtype=float32),
#               (4, 3): array([1090.2178], dtype=float32),
#               (4, 5): array([1562.4531], dtype=float32),
#               (5, 1): array([4406.346], dtype=float32),
#               (5, 2): array([2925.4612], dtype=float32),
#               (5, 3): array([3861.3057], dtype=float32),
#               (5, 4): array([4824.751], dtype=float32),
#               (0, 0): array([3382.2202], dtype=float32)},
#              (5, 5, 6): {(1, 2): array([2847.3179], dtype=float32),
#               (1, 3): array([6501.379], dtype=float32),
#               (1, 4): array([4269.154], dtype=float32),
#               (1, 5): array([2117.7585], dtype=float32),
#               (2, 1): array([3483.5469], dtype=float32),
#               (2, 3): array([6036.565], dtype=float32),
#               (2, 4): array([1452.5947], dtype=float32),
#               (2, 5): array([3770.6765], dtype=float32),
#               (3, 1): array([1776.5103], dtype=float32),
#               (3, 2): array([4638.771], dtype=float32),
#               (3, 4): array([2317.9934], dtype=float32),
#               (3, 5): array([1985.186], dtype=float32),
#               (4, 1): array([521.7039], dtype=float32),
#               (4, 2): array([486.83478], dtype=float32),
#               (4, 3): array([2639.399], dtype=float32),
#               (4, 5): array([2393.5063], dtype=float32),
#               (5, 1): array([4435.4287], dtype=float32),
#               (5, 2): array([5479.264], dtype=float32),
#               (5, 3): array([4623.8364], dtype=float32),
#               (5, 4): array([5422.9272], dtype=float32),
#               (0, 0): array([1929.6567], dtype=float32)},
#              (5, 14, 6): {(1, 2): array([7222.9326], dtype=float32),
#               (1, 3): array([2189.281], dtype=float32),
#               (1, 4): array([1837.4717], dtype=float32),
#               (1, 5): array([4610.5205], dtype=float32),
#               (2, 1): array([9971.8125], dtype=float32),
#               (2, 3): array([5345.3003], dtype=float32),
#               (2, 4): array([3874.3755], dtype=float32),
#               (2, 5): array([2580.973], dtype=float32),
#               (3, 1): array([6836.7593], dtype=float32),
#               (3, 2): array([3840.5222], dtype=float32),
#               (3, 4): array([9159.815], dtype=float32),
#               (3, 5): array([2957.703], dtype=float32),
#               (4, 1): array([1369.4465], dtype=float32),
#               (4, 2): array([1351.3832], dtype=float32),
#               (4, 3): array([2719.4443], dtype=float32),
#               (4, 5): array([1931.4585], dtype=float32),
#               (5, 1): array([4369.3477], dtype=float32),
#               (5, 2): array([3619.682], dtype=float32),
#               (5, 3): array([2625.1455], dtype=float32),
#               (5, 4): array([11151.7], dtype=float32),
#               (0, 0): array([7451.8657], dtype=float32)},
#              (4, 15, 6): {(1, 2): array([3762.928], dtype=float32),
#               (1, 3): array([10415.634], dtype=float32),
#               (1, 4): array([3346.9883], dtype=float32),
#               (1, 5): array([5097.255], dtype=float32),
#               (2, 1): array([3730.8684], dtype=float32),
#               (2, 3): array([6697.4824], dtype=float32),
#               (2, 4): array([1753.8293], dtype=float32),
#               (2, 5): array([2261.1064], dtype=float32),
#               (3, 1): array([4263.432], dtype=float32),
#               (3, 2): array([1395.5864], dtype=float32),
#               (3, 4): array([978.7009], dtype=float32),
#               (3, 5): array([941.0281], dtype=float32),
#               (4, 1): array([9209.105], dtype=float32),
#               (4, 2): array([3212.668], dtype=float32),
#               (4, 3): array([10929.491], dtype=float32),
#               (4, 5): array([6881.214], dtype=float32),
#               (5, 1): array([1065.6948], dtype=float32),
#               (5, 2): array([1405.4435], dtype=float32),
#               (5, 3): array([481.936], dtype=float32),
#               (5, 4): array([2828.0867], dtype=float32),
#               (0, 0): array([20124.787], dtype=float32)},
#              (2, 21, 6): {(1, 2): array([459.17838], dtype=float32),
#               (1, 3): array([1077.495], dtype=float32),
#               (1, 4): array([520.80444], dtype=float32),
#               (1, 5): array([2713.2512], dtype=float32),
#               (2, 1): array([5804.9497], dtype=float32),
#               (2, 3): array([20877.498], dtype=float32),
#               (2, 4): array([2557.9397], dtype=float32),
#               (2, 5): array([4373.287], dtype=float32),
#               (3, 1): 0,
#               (3, 2): array([1515.0944], dtype=float32),
#               (3, 4): array([456.424], dtype=float32),
#               (3, 5): array([831.53503], dtype=float32),
#               (4, 1): array([3083.53], dtype=float32),
#               (4, 2): array([959.8], dtype=float32),
#               (4, 3): array([2644.2805], dtype=float32),
#               (4, 5): array([3303.3452], dtype=float32),
#               (5, 1): array([459.32227], dtype=float32),
#               (5, 2): array([1929.9012], dtype=float32),
#               (5, 3): 0,
#               (5, 4): array([3088.7239], dtype=float32),
#               (0, 0): array([438.22098], dtype=float32)},
#              (2, 22, 6): {(1, 2): array([1272.832], dtype=float32),
#               (1, 3): array([1031.8948], dtype=float32),
#               (1, 4): array([438.03937], dtype=float32),
#               (1, 5): array([461.8999], dtype=float32),
#               (2, 1): array([5319.878], dtype=float32),
#               (2, 3): array([11801.424], dtype=float32),
#               (2, 4): array([1880.0582], dtype=float32),
#               (2, 5): array([1718.2893], dtype=float32),
#               (3, 1): array([574.57776], dtype=float32),
#               (3, 2): array([3887.4053], dtype=float32),
#               (3, 4): 0,
#               (3, 5): array([31.423475], dtype=float32),
#               (4, 1): array([1934.8153], dtype=float32),
#               (4, 2): array([1555.4438], dtype=float32),
#               (4, 3): array([1977.795], dtype=float32),
#               (4, 5): array([2683.8457], dtype=float32),
#               (5, 1): array([2183.4434], dtype=float32),
#               (5, 2): array([2299.007], dtype=float32),
#               (5, 3): array([2519.0823], dtype=float32),
#               (5, 4): array([928.17255], dtype=float32),
#               (0, 0): array([993.1497], dtype=float32)},
#              (1, 2, 6): {(1, 2): array([10816.724], dtype=float32),
#               (1, 3): array([10901.302], dtype=float32),
#               (1, 4): array([7892.255], dtype=float32),
#               (1, 5): array([6657.5146], dtype=float32),
#               (2, 1): array([3337.415], dtype=float32),
#               (2, 3): array([3135.846], dtype=float32),
#               (2, 4): array([2441.9146], dtype=float32),
#               (2, 5): array([1076.2064], dtype=float32),
#               (3, 1): array([1918.1293], dtype=float32),
#               (3, 2): array([2897.8467], dtype=float32),
#               (3, 4): array([2376.3748], dtype=float32),
#               (3, 5): array([1483.4617], dtype=float32),
#               (4, 1): array([1012.6941], dtype=float32),
#               (4, 2): array([1441.8268], dtype=float32),
#               (4, 3): array([1306.3518], dtype=float32),
#               (4, 5): array([2302.5305], dtype=float32),
#               (5, 1): array([2698.5906], dtype=float32),
#               (5, 2): array([4441.207], dtype=float32),
#               (5, 3): array([5624.9277], dtype=float32),
#               (5, 4): array([7579.7866], dtype=float32),
#               (0, 0): array([59854.3], dtype=float32)},
#              (1, 11, 6): {(1, 2): array([4885.579], dtype=float32),
#               (1, 3): array([4707.6167], dtype=float32),
#               (1, 4): array([6623.706], dtype=float32),
#               (1, 5): array([3906.9653], dtype=float32),
#               (2, 1): array([2463.835], dtype=float32),
#               (2, 3): array([3301.2854], dtype=float32),
#               (2, 4): 0,
#               (2, 5): 0,
#               (3, 1): 0,
#               (3, 2): array([456.3281], dtype=float32),
#               (3, 4): array([1330.2994], dtype=float32),
#               (3, 5): array([1461.298], dtype=float32),
#               (4, 1): array([5599.689], dtype=float32),
#               (4, 2): array([1638.2863], dtype=float32),
#               (4, 3): array([2359.7495], dtype=float32),
#               (4, 5): array([971.4195], dtype=float32),
#               (5, 1): array([1115.2043], dtype=float32),
#               (5, 2): array([3465.69], dtype=float32),
#               (5, 3): array([3202.5012], dtype=float32),
#               (5, 4): array([2522.8838], dtype=float32),
#               (0, 0): array([43528.168], dtype=float32)},
#              (5, 22, 6): {(1, 2): array([3766.9065], dtype=float32),
#               (1, 3): array([2850.1338], dtype=float32),
#               (1, 4): array([2642.652], dtype=float32),
#               (1, 5): array([2084.703], dtype=float32),
#               (2, 1): array([2169.4604], dtype=float32),
#               (2, 3): array([6314.9985], dtype=float32),
#               (2, 4): array([1836.584], dtype=float32),
#               (2, 5): array([2070.1921], dtype=float32),
#               (3, 1): array([971.07715], dtype=float32),
#               (3, 2): array([3199.2659], dtype=float32),
#               (3, 4): array([1976.3816], dtype=float32),
#               (3, 5): array([452.42014], dtype=float32),
#               (4, 1): array([2674.2412], dtype=float32),
#               (4, 2): array([1147.2574], dtype=float32),
#               (4, 3): array([2011.6832], dtype=float32),
#               (4, 5): array([2718.8567], dtype=float32),
#               (5, 1): array([5369.3633], dtype=float32),
#               (5, 2): array([4088.0173], dtype=float32),
#               (5, 3): array([3536.2344], dtype=float32),
#               (5, 4): array([6692.0537], dtype=float32),
#               (0, 0): array([4966.6685], dtype=float32)},
#              (1, 3, 6): {(1, 2): array([7262.6797], dtype=float32),
#               (1, 3): array([5850.381], dtype=float32),
#               (1, 4): array([6239.716], dtype=float32),
#               (1, 5): array([2018.3372], dtype=float32),
#               (2, 1): array([5268.6016], dtype=float32),
#               (2, 3): array([3285.7275], dtype=float32),
#               (2, 4): array([3543.2236], dtype=float32),
#               (2, 5): 0,
#               (3, 1): array([1140.8298], dtype=float32),
#               (3, 2): array([968.8492], dtype=float32),
#               (3, 4): array([2016.5332], dtype=float32),
#               (3, 5): array([1503.9495], dtype=float32),
#               (4, 1): array([2231.5188], dtype=float32),
#               (4, 2): array([2783.3672], dtype=float32),
#               (4, 3): array([1802.1909], dtype=float32),
#               (4, 5): array([4197.279], dtype=float32),
#               (5, 1): array([4207.305], dtype=float32),
#               (5, 2): array([3537.3413], dtype=float32),
#               (5, 3): array([1865.6865], dtype=float32),
#               (5, 4): array([5410.3247], dtype=float32),
#               (0, 0): array([47287.45], dtype=float32)},
#              (5, 16, 6): {(1, 2): array([2139.3657], dtype=float32),
#               (1, 3): array([2669.9692], dtype=float32),
#               (1, 4): array([3004.8604], dtype=float32),
#               (1, 5): array([2629.638], dtype=float32),
#               (2, 1): array([9509.216], dtype=float32),
#               (2, 3): array([11248.155], dtype=float32),
#               (2, 4): array([2745.9246], dtype=float32),
#               (2, 5): array([1697.0848], dtype=float32),
#               (3, 1): array([4123.5513], dtype=float32),
#               (3, 2): array([4786.273], dtype=float32),
#               (3, 4): array([11184.77], dtype=float32),
#               (3, 5): array([6222.3228], dtype=float32),
#               (4, 1): array([986.048], dtype=float32),
#               (4, 2): array([862.0762], dtype=float32),
#               (4, 3): array([2875.4504], dtype=float32),
#               (4, 5): array([3722.0342], dtype=float32),
#               (5, 1): array([11054.336], dtype=float32),
#               (5, 2): array([5466.6055], dtype=float32),
#               (5, 3): array([3853.4084], dtype=float32),
#               (5, 4): array([22680.36], dtype=float32),
#               (0, 0): array([8659.772], dtype=float32)},
#              (5, 17, 6): {(1, 2): array([5601.5073], dtype=float32),
#               (1, 3): array([8611.544], dtype=float32),
#               (1, 4): array([6748.261], dtype=float32),
#               (1, 5): array([5205.714], dtype=float32),
#               (2, 1): array([8834.892], dtype=float32),
#               (2, 3): array([7962.054], dtype=float32),
#               (2, 4): array([2480.6077], dtype=float32),
#               (2, 5): array([3037.81], dtype=float32),
#               (3, 1): array([4219.8896], dtype=float32),
#               (3, 2): array([7566.5474], dtype=float32),
#               (3, 4): array([5393.5425], dtype=float32),
#               (3, 5): array([2739.7505], dtype=float32),
#               (4, 1): array([3385.7505], dtype=float32),
#               (4, 2): array([1372.7278], dtype=float32),
#               (4, 3): array([3315.0632], dtype=float32),
#               (4, 5): array([5318.4863], dtype=float32),
#               (5, 1): array([5582.6743], dtype=float32),
#               (5, 2): array([4966.7764], dtype=float32),
#               (5, 3): array([5049.3003], dtype=float32),
#               (5, 4): array([16726.314], dtype=float32),
#               (0, 0): array([7340.8325], dtype=float32)},
#              (5, 2, 0): {(1, 2): array([7091.4453], dtype=float32),
#               (1, 3): array([7610.1274], dtype=float32),
#               (1, 4): array([7104.2686], dtype=float32),
#               (1, 5): array([566.9841], dtype=float32),
#               (2, 1): array([6384.6396], dtype=float32),
#               (2, 3): array([8523.413], dtype=float32),
#               (2, 4): array([3294.6914], dtype=float32),
#               (2, 5): array([3568.8242], dtype=float32),
#               (3, 1): array([2968.3599], dtype=float32),
#               (3, 2): array([8177.3486], dtype=float32),
#               (3, 4): array([5556.3643], dtype=float32),
#               (3, 5): array([3592.7368], dtype=float32),
#               (4, 1): array([3242.2637], dtype=float32),
#               (4, 2): array([2379.18], dtype=float32),
#               (4, 3): array([482.2737], dtype=float32),
#               (4, 5): array([1789.4966], dtype=float32),
#               (5, 1): array([3635.4458], dtype=float32),
#               (5, 2): array([5984.1875], dtype=float32),
#               (5, 3): array([6581.7593], dtype=float32),
#               (5, 4): array([13413.544], dtype=float32),
#               (0, 0): array([7017.933], dtype=float32)},
#              (5, 6, 0): {(1, 2): array([5585.2134], dtype=float32),
#               (1, 3): array([2809.0679], dtype=float32),
#               (1, 4): array([2019.1943], dtype=float32),
#               (1, 5): array([2653.5168], dtype=float32),
#               (2, 1): array([933.0464], dtype=float32),
#               (2, 3): array([485.92145], dtype=float32),
#               (2, 4): array([1657.9258], dtype=float32),
#               (2, 5): array([1497.34], dtype=float32),
#               (3, 1): array([3758.3113], dtype=float32),
#               (3, 2): array([905.6221], dtype=float32),
#               (3, 4): array([5004.4004], dtype=float32),
#               (3, 5): array([1440.7917], dtype=float32),
#               (4, 1): 0,
#               (4, 2): array([3458.6099], dtype=float32),
#               (4, 3): array([950.3174], dtype=float32),
#               (4, 5): array([1264.5986], dtype=float32),
#               (5, 1): array([2320.7642], dtype=float32),
#               (5, 2): array([2779.983], dtype=float32),
#               (5, 3): array([455.24847], dtype=float32),
#               (5, 4): array([9669.763], dtype=float32),
#               (0, 0): array([3864.412], dtype=float32)},
#              (5, 12, 0): {(1, 2): array([3147.7395], dtype=float32),
#               (1, 3): array([446.78976], dtype=float32),
#               (1, 4): array([1540.0419], dtype=float32),
#               (1, 5): array([2648.827], dtype=float32),
#               (2, 1): array([898.2288], dtype=float32),
#               (2, 3): array([2997.3152], dtype=float32),
#               (2, 4): array([2858.155], dtype=float32),
#               (2, 5): array([2132.2205], dtype=float32),
#               (3, 1): array([473.469], dtype=float32),
#               (3, 2): array([1265.6527], dtype=float32),
#               (3, 4): array([3179.7278], dtype=float32),
#               (3, 5): array([516.21765], dtype=float32),
#               (4, 1): 0,
#               (4, 2): array([1169.7244], dtype=float32),
#               (4, 3): array([526.96857], dtype=float32),
#               (4, 5): array([1724.5415], dtype=float32),
#               (5, 1): array([1314.9152], dtype=float32),
#               (5, 2): array([2633.937], dtype=float32),
#               (5, 3): array([2519.3206], dtype=float32),
#               (5, 4): array([3033.7212], dtype=float32),
#               (0, 0): array([4312.7163], dtype=float32)},
#              (3, 13, 0): {(1, 2): array([2104.065], dtype=float32),
#               (1, 3): array([2183.4873], dtype=float32),
#               (1, 4): array([2986.1619], dtype=float32),
#               (1, 5): 0,
#               (2, 1): array([3326.0227], dtype=float32),
#               (2, 3): array([2301.539], dtype=float32),
#               (2, 4): array([897.5067], dtype=float32),
#               (2, 5): array([1363.9531], dtype=float32),
#               (3, 1): array([4866.0034], dtype=float32),
#               (3, 2): array([9352.063], dtype=float32),
#               (3, 4): array([8402.126], dtype=float32),
#               (3, 5): array([3760.8298], dtype=float32),
#               (4, 1): array([1891.5735], dtype=float32),
#               (4, 2): array([857.41113], dtype=float32),
#               (4, 3): array([432.1253], dtype=float32),
#               (4, 5): array([0.32643756], dtype=float32),
#               (5, 1): array([3653.1868], dtype=float32),
#               (5, 2): array([2544.469], dtype=float32),
#               (5, 3): array([4212.286], dtype=float32),
#               (5, 4): array([6267.3735], dtype=float32),
#               (0, 0): array([29285.104], dtype=float32)},
#              (5, 3, 1): {(1, 2): array([7779.611], dtype=float32),
#               (1, 3): array([6728.5522], dtype=float32),
#               (1, 4): array([1215.4552], dtype=float32),
#               (1, 5): array([2658.9973], dtype=float32),
#               (2, 1): array([2363.814], dtype=float32),
#               (2, 3): array([5230.1323], dtype=float32),
#               (2, 4): array([1428.0948], dtype=float32),
#               (2, 5): array([439.62784], dtype=float32),
#               (3, 1): array([4129.9556], dtype=float32),
#               (3, 2): array([6854.578], dtype=float32),
#               (3, 4): array([3672.968], dtype=float32),
#               (3, 5): array([7437.875], dtype=float32),
#               (4, 1): array([4181.9985], dtype=float32),
#               (4, 2): array([2548.2925], dtype=float32),
#               (4, 3): array([2080.7588], dtype=float32),
#               (4, 5): array([3474.376], dtype=float32),
#               (5, 1): array([3057.5623], dtype=float32),
#               (5, 2): array([7724.8037], dtype=float32),
#               (5, 3): array([2322.8867], dtype=float32),
#               (5, 4): array([4691.009], dtype=float32),
#               (0, 0): array([7087.7646], dtype=float32)},
#              (1, 9, 1): {(1, 2): array([7780.0527], dtype=float32),
#               (1, 3): array([8829.857], dtype=float32),
#               (1, 4): array([1959.9591], dtype=float32),
#               (1, 5): array([3710.3818], dtype=float32),
#               (2, 1): array([511.78973], dtype=float32),
#               (2, 3): array([2428.6313], dtype=float32),
#               (2, 4): array([593.39075], dtype=float32),
#               (2, 5): array([546.5973], dtype=float32),
#               (3, 1): array([1299.5244], dtype=float32),
#               (3, 2): array([947.95886], dtype=float32),
#               (3, 4): 0,
#               (3, 5): 0,
#               (4, 1): array([1076.9938], dtype=float32),
#               (4, 2): array([2270.5386], dtype=float32),
#               (4, 3): array([2434.248], dtype=float32),
#               (4, 5): array([1060.587], dtype=float32),
#               (5, 1): array([1864.8081], dtype=float32),
#               (5, 2): array([2291.8086], dtype=float32),
#               (5, 3): array([2869.6433], dtype=float32),
#               (5, 4): array([1478.3942], dtype=float32),
#               (0, 0): array([62243.207], dtype=float32)},
#              (1, 23, 1): {(1, 2): array([5150.948], dtype=float32),
#               (1, 3): array([14878.057], dtype=float32),
#               (1, 4): array([4894.374], dtype=float32),
#               (1, 5): array([7465.579], dtype=float32),
#               (2, 1): array([2628.735], dtype=float32),
#               (2, 3): array([9573.684], dtype=float32),
#               (2, 4): array([1472.8108], dtype=float32),
#               (2, 5): array([1767.2511], dtype=float32),
#               (3, 1): array([1638.4226], dtype=float32),
#               (3, 2): array([5053.0786], dtype=float32),
#               (3, 4): array([1882.054], dtype=float32),
#               (3, 5): array([2843.6177], dtype=float32),
#               (4, 1): array([7513.4277], dtype=float32),
#               (4, 2): array([6125.3364], dtype=float32),
#               (4, 3): array([5390.8994], dtype=float32),
#               (4, 5): array([4447.8374], dtype=float32),
#               (5, 1): array([2074.563], dtype=float32),
#               (5, 2): array([3543.3567], dtype=float32),
#               (5, 3): array([3687.9084], dtype=float32),
#               (5, 4): array([906.4317], dtype=float32),
#               (0, 0): array([59439.605], dtype=float32)},
#              (5, 2, 1): {(1, 2): array([8690.26], dtype=float32),
#               (1, 3): array([6626.408], dtype=float32),
#               (1, 4): array([5880.2866], dtype=float32),
#               (1, 5): array([2155.4543], dtype=float32),
#               (2, 1): array([4525.0747], dtype=float32),
#               (2, 3): array([21501.516], dtype=float32),
#               (2, 4): array([3230.8071], dtype=float32),
#               (2, 5): array([3644.0085], dtype=float32),
#               (3, 1): array([2361.9565], dtype=float32),
#               (3, 2): array([16453.113], dtype=float32),
#               (3, 4): array([5171.0576], dtype=float32),
#               (3, 5): array([3633.5464], dtype=float32),
#               (4, 1): array([2406.5413], dtype=float32),
#               (4, 2): array([1091.9575], dtype=float32),
#               (4, 3): array([5245.079], dtype=float32),
#               (4, 5): array([3909.7156], dtype=float32),
#               (5, 1): array([6280.274], dtype=float32),
#               (5, 2): array([8321.081], dtype=float32),
#               (5, 3): array([5730.228], dtype=float32),
#               (5, 4): array([15207.93], dtype=float32),
#               (0, 0): array([6827.6978], dtype=float32)},
#              (4, 9, 1): {(1, 2): array([811.75226], dtype=float32),
#               (1, 3): array([675.51514], dtype=float32),
#               (1, 4): array([486.368], dtype=float32),
#               (1, 5): array([1618.4006], dtype=float32),
#               (2, 1): array([2005.0123], dtype=float32),
#               (2, 3): array([7625.9697], dtype=float32),
#               (2, 4): array([1969.8713], dtype=float32),
#               (2, 5): array([2647.8298], dtype=float32),
#               (3, 1): array([2149.2983], dtype=float32),
#               (3, 2): array([3017.3674], dtype=float32),
#               (3, 4): array([1800.5804], dtype=float32),
#               (3, 5): array([2965.1064], dtype=float32),
#               (4, 1): array([5553.4077], dtype=float32),
#               (4, 2): array([10551.616], dtype=float32),
#               (4, 3): array([15083.596], dtype=float32),
#               (4, 5): array([12055.178], dtype=float32),
#               (5, 1): array([1837.6831], dtype=float32),
#               (5, 2): array([1461.6003], dtype=float32),
#               (5, 3): array([2646.1187], dtype=float32),
#               (5, 4): array([3516.8726], dtype=float32),
#               (0, 0): array([9266.311], dtype=float32)},
#              (4, 13, 1): {(1, 2): 0,
#               (1, 3): array([3673.2258], dtype=float32),
#               (1, 4): array([449.5137], dtype=float32),
#               (1, 5): 0,
#               (2, 1): array([2916.3892], dtype=float32),
#               (2, 3): array([3580.3455], dtype=float32),
#               (2, 4): array([1462.9882], dtype=float32),
#               (2, 5): array([1413.3027], dtype=float32),
#               (3, 1): array([2454.501], dtype=float32),
#               (3, 2): array([2292.3289], dtype=float32),
#               (3, 4): array([1864.2417], dtype=float32),
#               (3, 5): array([2786.3584], dtype=float32),
#               (4, 1): array([3057.7146], dtype=float32),
#               (4, 2): array([2575.3594], dtype=float32),
#               (4, 3): array([10550.516], dtype=float32),
#               (4, 5): array([6719.258], dtype=float32),
#               (5, 1): array([378.35052], dtype=float32),
#               (5, 2): array([512.4782], dtype=float32),
#               (5, 3): array([420.50943], dtype=float32),
#               (5, 4): array([447.8429], dtype=float32),
#               (0, 0): array([4256.6157], dtype=float32)},
#              (4, 17, 1): {(1, 2): array([2648.471], dtype=float32),
#               (1, 3): array([3329.7217], dtype=float32),
#               (1, 4): array([1039.8115], dtype=float32),
#               (1, 5): array([997.8845], dtype=float32),
#               (2, 1): array([2249.2744], dtype=float32),
#               (2, 3): array([3654.444], dtype=float32),
#               (2, 4): array([1202.5344], dtype=float32),
#               (2, 5): array([1466.7874], dtype=float32),
#               (3, 1): array([2077.9844], dtype=float32),
#               (3, 2): array([1439.6229], dtype=float32),
#               (3, 4): array([274.3203], dtype=float32),
#               (3, 5): array([711.54376], dtype=float32),
#               (4, 1): array([9121.002], dtype=float32),
#               (4, 2): array([2618.2505], dtype=float32),
#               (4, 3): array([8526.46], dtype=float32),
#               (4, 5): array([9535.529], dtype=float32),
#               (5, 1): array([424.52444], dtype=float32),
#               (5, 2): array([552.91656], dtype=float32),
#               (5, 3): array([2168.546], dtype=float32),
#               (5, 4): array([1457.7457], dtype=float32),
#               (0, 0): array([6876.5996], dtype=float32)},
#              (2, 19, 1): {(1, 2): array([1803.4381], dtype=float32),
#               (1, 3): array([1929.7556], dtype=float32),
#               (1, 4): array([2537.0166], dtype=float32),
#               (1, 5): array([1881.6954], dtype=float32),
#               (2, 1): array([10291.808], dtype=float32),
#               (2, 3): array([24500.854], dtype=float32),
#               (2, 4): array([4622.4175], dtype=float32),
#               (2, 5): array([6117.602], dtype=float32),
#               (3, 1): 0,
#               (3, 2): array([1035.4067], dtype=float32),
#               (3, 4): array([549.91486], dtype=float32),
#               (3, 5): array([1980.0925], dtype=float32),
#               (4, 1): array([1067.2219], dtype=float32),
#               (4, 2): array([1902.9836], dtype=float32),
#               (4, 3): array([3856.8965], dtype=float32),
#               (4, 5): array([3858.3862], dtype=float32),
#               (5, 1): array([1488.135], dtype=float32),
#               (5, 2): array([2808.342], dtype=float32),
#               (5, 3): array([1935.2834], dtype=float32),
#               (5, 4): array([7513.618], dtype=float32),
#               (0, 0): array([3408.1694], dtype=float32)},
#              (4, 21, 1): {(1, 2): array([976.49713], dtype=float32),
#               (1, 3): array([2131.282], dtype=float32),
#               (1, 4): array([2682.785], dtype=float32),
#               (1, 5): array([1840.8242], dtype=float32),
#               (2, 1): array([3617.5325], dtype=float32),
#               (2, 3): array([3303.5403], dtype=float32),
#               (2, 4): array([2015.8796], dtype=float32),
#               (2, 5): array([1049.0635], dtype=float32),
#               (3, 1): array([2225.3643], dtype=float32),
#               (3, 2): array([3865.73], dtype=float32),
#               (3, 4): array([2070.0342], dtype=float32),
#               (3, 5): array([975.1948], dtype=float32),
#               (4, 1): array([6990.833], dtype=float32),
#               (4, 2): array([5165.259], dtype=float32),
#               (4, 3): array([16000.182], dtype=float32),
#               (4, 5): array([9219.315], dtype=float32),
#               (5, 1): array([1023.13617], dtype=float32),
#               (5, 2): array([937.44037], dtype=float32),
#               (5, 3): array([891.9954], dtype=float32),
#               (5, 4): array([3320.9702], dtype=float32),
#               (0, 0): array([8912.002], dtype=float32)},
#              (5, 23, 1): {(1, 2): array([4032.0574], dtype=float32),
#               (1, 3): array([3786.3545], dtype=float32),
#               (1, 4): array([5076.463], dtype=float32),
#               (1, 5): array([2580.5798], dtype=float32),
#               (2, 1): array([2226.3137], dtype=float32),
#               (2, 3): array([7919.3774], dtype=float32),
#               (2, 4): array([1261.0095], dtype=float32),
#               (2, 5): array([4700.297], dtype=float32),
#               (3, 1): array([1009.41064], dtype=float32),
#               (3, 2): array([6313.407], dtype=float32),
#               (3, 4): array([5942.336], dtype=float32),
#               (3, 5): array([1400.517], dtype=float32),
#               (4, 1): array([1606.036], dtype=float32),
#               (4, 2): array([942.4393], dtype=float32),
#               (4, 3): array([1213.5548], dtype=float32),
#               (4, 5): array([3842.2788], dtype=float32),
#               (5, 1): array([893.678], dtype=float32),
#               (5, 2): array([1181.2549], dtype=float32),
#               (5, 3): array([2298.259], dtype=float32),
#               (5, 4): array([8835.749], dtype=float32),
#               (0, 0): array([9973.136], dtype=float32)},
#              (2, 23, 1): {(1, 2): array([447.03754], dtype=float32),
#               (1, 3): array([481.5274], dtype=float32),
#               (1, 4): 0,
#               (1, 5): array([553.4967], dtype=float32),
#               (2, 1): array([4260.8525], dtype=float32),
#               (2, 3): array([21736.887], dtype=float32),
#               (2, 4): array([3210.247], dtype=float32),
#               (2, 5): array([4589.351], dtype=float32),
#               (3, 1): array([1623.9275], dtype=float32),
#               (3, 2): array([1497.3702], dtype=float32),
#               (3, 4): array([473.66824], dtype=float32),
#               (3, 5): array([1954.8964], dtype=float32),
#               (4, 1): array([3905.81], dtype=float32),
#               (4, 2): array([1969.2015], dtype=float32),
#               (4, 3): array([5876.81], dtype=float32),
#               (4, 5): array([5323.551], dtype=float32),
#               (5, 1): array([1519.4896], dtype=float32),
#               (5, 2): 0,
#               (5, 3): array([588.2782], dtype=float32),
#               (5, 4): array([4546.321], dtype=float32),
#               (0, 0): array([3303.6404], dtype=float32)},
#              (3, 1, 2): {(1, 2): array([1509.0865], dtype=float32),
#               (1, 3): array([1975.4391], dtype=float32),
#               (1, 4): array([1616.4683], dtype=float32),
#               (1, 5): array([1231.1545], dtype=float32),
#               (2, 1): array([2520.6885], dtype=float32),
#               (2, 3): array([2773.6753], dtype=float32),
#               (2, 4): array([458.87738], dtype=float32),
#               (2, 5): array([2667.128], dtype=float32),
#               (3, 1): array([10762.684], dtype=float32),
#               (3, 2): array([10197.305], dtype=float32),
#               (3, 4): array([7631.0024], dtype=float32),
#               (3, 5): array([3607.3499], dtype=float32),
#               (4, 1): 0,
#               (4, 2): array([1452.6628], dtype=float32),
#               (4, 3): array([1424.2866], dtype=float32),
#               (4, 5): array([1501.7506], dtype=float32),
#               (5, 1): array([2955.2346], dtype=float32),
#               (5, 2): array([3082.8933], dtype=float32),
#               (5, 3): array([1882.4646], dtype=float32),
#               (5, 4): array([3910.8613], dtype=float32),
#               (0, 0): array([40895.992], dtype=float32)},
#              (4, 8, 2): {(1, 2): array([2421.4548], dtype=float32),
#               (1, 3): array([1878.6482], dtype=float32),
#               (1, 4): array([923.61383], dtype=float32),
#               (1, 5): array([2034.4056], dtype=float32),
#               (2, 1): array([2517.9077], dtype=float32),
#               (2, 3): array([3915.3625], dtype=float32),
#               (2, 4): array([921.93945], dtype=float32),
#               (2, 5): array([1976.614], dtype=float32),
#               (3, 1): array([2399.8528], dtype=float32),
#               (3, 2): array([2797.8508], dtype=float32),
#               (3, 4): array([2772.3818], dtype=float32),
#               (3, 5): array([1551.1501], dtype=float32),
#               (4, 1): array([5332.6855], dtype=float32),
#               (4, 2): array([6826.0854], dtype=float32),
#               (4, 3): array([10657.437], dtype=float32),
#               (4, 5): array([7880.2266], dtype=float32),
#               (5, 1): array([476.19443], dtype=float32),
#               (5, 2): array([1594.8081], dtype=float32),
#               (5, 3): array([1907.588], dtype=float32),
#               (5, 4): 0,
#               (0, 0): array([10223.447], dtype=float32)},
#              (5, 14, 2): {(1, 2): array([4656.6924], dtype=float32),
#               (1, 3): array([3914.1223], dtype=float32),
#               (1, 4): array([6998.7417], dtype=float32),
#               (1, 5): array([2157.5295], dtype=float32),
#               (2, 1): array([5967.263], dtype=float32),
#               (2, 3): array([3712.6042], dtype=float32),
#               (2, 4): array([5038.8467], dtype=float32),
#               (2, 5): array([2729.2954], dtype=float32),
#               (3, 1): array([2505.777], dtype=float32),
#               (3, 2): array([2380.628], dtype=float32),
#               (3, 4): array([5441.3594], dtype=float32),
#               (3, 5): array([1425.0632], dtype=float32),
#               (4, 1): array([4183.9023], dtype=float32),
#               (4, 2): array([2033.5791], dtype=float32),
#               (4, 3): array([1411.9218], dtype=float32),
#               (4, 5): array([1083.3784], dtype=float32),
#               (5, 1): array([10120.986], dtype=float32),
#               (5, 2): array([3928.0967], dtype=float32),
#               (5, 3): array([3651.1938], dtype=float32),
#               (5, 4): array([8687.391], dtype=float32),
#               (0, 0): array([9526.536], dtype=float32)},
#              (1, 20, 2): {(1, 2): array([9199.356], dtype=float32),
#               (1, 3): array([7979.707], dtype=float32),
#               (1, 4): array([4371.9614], dtype=float32),
#               (1, 5): array([5785.745], dtype=float32),
#               (2, 1): array([3038.9802], dtype=float32),
#               (2, 3): array([8796.832], dtype=float32),
#               (2, 4): array([1924.8701], dtype=float32),
#               (2, 5): 0,
#               (3, 1): array([2880.798], dtype=float32),
#               (3, 2): array([1516.4978], dtype=float32),
#               (3, 4): array([904.80066], dtype=float32),
#               (3, 5): array([1937.5515], dtype=float32),
#               (4, 1): array([5593.131], dtype=float32),
#               (4, 2): array([5849.484], dtype=float32),
#               (4, 3): array([7524.1763], dtype=float32),
#               (4, 5): array([5352.2734], dtype=float32),
#               (5, 1): array([1918.3784], dtype=float32),
#               (5, 2): array([2768.602], dtype=float32),
#               (5, 3): array([4871.576], dtype=float32),
#               (5, 4): array([4133.1016], dtype=float32),
#               (0, 0): array([68509.71], dtype=float32)},
#              (1, 21, 2): {(1, 2): array([7021.299], dtype=float32),
#               (1, 3): array([9708.724], dtype=float32),
#               (1, 4): array([7247.6045], dtype=float32),
#               (1, 5): array([4187.0747], dtype=float32),
#               (2, 1): array([2639.8887], dtype=float32),
#               (2, 3): array([5205.631], dtype=float32),
#               (2, 4): 0,
#               (2, 5): array([1086.4171], dtype=float32),
#               (3, 1): array([1396.6731], dtype=float32),
#               (3, 2): array([1402.8678], dtype=float32),
#               (3, 4): array([586.8594], dtype=float32),
#               (3, 5): array([2694.324], dtype=float32),
#               (4, 1): array([1930.8594], dtype=float32),
#               (4, 2): array([3534.849], dtype=float32),
#               (4, 3): array([8640.856], dtype=float32),
#               (4, 5): array([1873.9142], dtype=float32),
#               (5, 1): array([1376.7039], dtype=float32),
#               (5, 2): array([1508.3792], dtype=float32),
#               (5, 3): array([2383.4497], dtype=float32),
#               (5, 4): array([4919.9], dtype=float32),
#               (0, 0): array([70256.08], dtype=float32)},
#              (1, 8, 2): {(1, 2): array([7100.5977], dtype=float32),
#               (1, 3): array([5100.3105], dtype=float32),
#               (1, 4): array([3349.8599], dtype=float32),
#               (1, 5): array([3082.4814], dtype=float32),
#               (2, 1): array([935.44196], dtype=float32),
#               (2, 3): array([2304.6108], dtype=float32),
#               (2, 4): array([875.3892], dtype=float32),
#               (2, 5): array([680.4736], dtype=float32),
#               (3, 1): array([903.2566], dtype=float32),
#               (3, 2): array([2622.0972], dtype=float32),
#               (3, 4): array([872.64954], dtype=float32),
#               (3, 5): array([1483.8485], dtype=float32),
#               (4, 1): array([1130.4818], dtype=float32),
#               (4, 2): array([895.51404], dtype=float32),
#               (4, 3): array([3359.701], dtype=float32),
#               (4, 5): array([2033.4568], dtype=float32),
#               (5, 1): 0,
#               (5, 2): array([1274.4996], dtype=float32),
#               (5, 3): array([431.22424], dtype=float32),
#               (5, 4): array([1999.2659], dtype=float32),
#               (0, 0): array([45404.79], dtype=float32)},
#              (2, 17, 2): {(1, 2): array([1492.8641], dtype=float32),
#               (1, 3): array([1958.6199], dtype=float32),
#               (1, 4): array([3161.0283], dtype=float32),
#               (1, 5): array([1067.6936], dtype=float32),
#               (2, 1): array([16701.566], dtype=float32),
#               (2, 3): array([12711.768], dtype=float32),
#               (2, 4): array([6834.883], dtype=float32),
#               (2, 5): array([4798.136], dtype=float32),
#               (3, 1): array([1177.0945], dtype=float32),
#               (3, 2): array([4036.026], dtype=float32),
#               (3, 4): array([920.51685], dtype=float32),
#               (3, 5): array([2103.3933], dtype=float32),
#               (4, 1): array([479.47708], dtype=float32),
#               (4, 2): array([1105.7816], dtype=float32),
#               (4, 3): array([835.0166], dtype=float32),
#               (4, 5): array([2548.918], dtype=float32),
#               (5, 1): array([2868.8506], dtype=float32),
#               (5, 2): array([1506.8704], dtype=float32),
#               (5, 3): array([1645.2881], dtype=float32),
#               (5, 4): array([8639.155], dtype=float32),
#               (0, 0): array([2011.6786], dtype=float32)},
#              (5, 20, 2): {(1, 2): array([571.80286], dtype=float32),
#               (1, 3): 0,
#               (1, 4): 0,
#               (1, 5): 0,
#               (2, 1): array([2993.3042], dtype=float32),
#               (2, 3): array([7535.2085], dtype=float32),
#               (2, 4): array([473.05527], dtype=float32),
#               (2, 5): array([459.16232], dtype=float32),
#               (3, 1): array([2957.9363], dtype=float32),
#               (3, 2): array([4218.07], dtype=float32),
#               (3, 4): array([824.7776], dtype=float32),
#               (3, 5): array([415.34863], dtype=float32),
#               (4, 1): array([1694.6995], dtype=float32),
#               (4, 2): array([941.84143], dtype=float32),
# ...
#               (4, 1): 0,
#               (4, 2): 0,
#               (4, 3): 0,
#               (4, 5): array([457.16806], dtype=float32),
#               (5, 1): array([1081.6615], dtype=float32),
#               (5, 2): array([1972.8552], dtype=float32),
#               (5, 3): array([480.04187], dtype=float32),
#               (5, 4): array([1094.713], dtype=float32),
#               (0, 0): array([993.04065], dtype=float32)},
#              (5, 12, 4): {(1, 2): 0,
#               (1, 3): array([1446.1489], dtype=float32),
#               (1, 4): array([971.8746], dtype=float32),
#               (1, 5): array([895.406], dtype=float32),
#               (2, 1): 0,
#               (2, 3): array([1901.5967], dtype=float32),
#               (2, 4): array([2062.8228], dtype=float32),
#               (2, 5): array([1041.8885], dtype=float32),
#               (3, 1): array([942.1225], dtype=float32),
#               (3, 2): array([600.7653], dtype=float32),
#               (3, 4): array([2512.63], dtype=float32),
#               (3, 5): array([586.0058], dtype=float32),
#               (4, 1): array([451.33142], dtype=float32),
#               (4, 2): array([478.67438], dtype=float32),
#               (4, 3): 0,
#               (4, 5): array([490.0117], dtype=float32),
#               (5, 1): array([1281.9512], dtype=float32),
#               (5, 2): array([1953.4983], dtype=float32),
#               (5, 3): array([2595.9463], dtype=float32),
#               (5, 4): array([2372.6243], dtype=float32),
#               (0, 0): array([886.2101], dtype=float32)},
#              (1, 22, 0): {(1, 2): array([8454.576], dtype=float32),
#               (1, 3): array([7895.955], dtype=float32),
#               (1, 4): array([2884.1924], dtype=float32),
#               (1, 5): array([7770.812], dtype=float32),
#               (2, 1): array([2305.9978], dtype=float32),
#               (2, 3): array([3924.279], dtype=float32),
#               (2, 4): array([422.28265], dtype=float32),
#               (2, 5): array([1142.7354], dtype=float32),
#               (3, 1): array([521.43146], dtype=float32),
#               (3, 2): array([902.4459], dtype=float32),
#               (3, 4): array([1300.1216], dtype=float32),
#               (3, 5): array([1393.6135], dtype=float32),
#               (4, 1): array([1866.929], dtype=float32),
#               (4, 2): array([473.93954], dtype=float32),
#               (4, 3): array([3252.89], dtype=float32),
#               (4, 5): array([992.952], dtype=float32),
#               (5, 1): array([1009.08374], dtype=float32),
#               (5, 2): array([1534.5334], dtype=float32),
#               (5, 3): array([1719.7128], dtype=float32),
#               (5, 4): array([480.4697], dtype=float32),
#               (0, 0): array([33232.89], dtype=float32)},
#              (2, 12, 1): {(1, 2): 0,
#               (1, 3): 0,
#               (1, 4): array([1207.0074], dtype=float32),
#               (1, 5): 0,
#               (2, 1): array([3746.6775], dtype=float32),
#               (2, 3): array([8206.472], dtype=float32),
#               (2, 4): array([2274.2307], dtype=float32),
#               (2, 5): array([566.4342], dtype=float32),
#               (3, 1): array([457.00876], dtype=float32),
#               (3, 2): array([1835.2118], dtype=float32),
#               (3, 4): array([328.8392], dtype=float32),
#               (3, 5): array([510.2884], dtype=float32),
#               (4, 1): array([834.1194], dtype=float32),
#               (4, 2): 0,
#               (4, 3): 0,
#               (4, 5): array([3059.8787], dtype=float32),
#               (5, 1): array([2601.2534], dtype=float32),
#               (5, 2): array([3050.0173], dtype=float32),
#               (5, 3): array([2519.6948], dtype=float32),
#               (5, 4): array([3300.9785], dtype=float32),
#               (0, 0): array([635.3662], dtype=float32)},
#              (2, 0, 1): {(1, 2): array([1640.6815], dtype=float32),
#               (1, 3): 0,
#               (1, 4): 0,
#               (1, 5): 0,
#               (2, 1): array([6426.7407], dtype=float32),
#               (2, 3): array([36656.816], dtype=float32),
#               (2, 4): array([4621.2817], dtype=float32),
#               (2, 5): array([6222.222], dtype=float32),
#               (3, 1): array([509.66623], dtype=float32),
#               (3, 2): array([1454.5255], dtype=float32),
#               (3, 4): array([2156.9246], dtype=float32),
#               (3, 5): 0,
#               (4, 1): array([1549.7458], dtype=float32),
#               (4, 2): array([531.0915], dtype=float32),
#               (4, 3): array([4367.0337], dtype=float32),
#               (4, 5): array([412.8895], dtype=float32),
#               (5, 1): array([1025.9159], dtype=float32),
#               (5, 2): array([2643.6409], dtype=float32),
#               (5, 3): array([1478.7924], dtype=float32),
#               (5, 4): array([2948.9934], dtype=float32),
#               (0, 0): array([4524.4653], dtype=float32)},
#              (4, 2, 2): {(1, 2): array([493.8192], dtype=float32),
#               (1, 3): array([929.0368], dtype=float32),
#               (1, 4): 0,
#               (1, 5): array([528.205], dtype=float32),
#               (2, 1): array([2501.1997], dtype=float32),
#               (2, 3): array([551.0442], dtype=float32),
#               (2, 4): array([1494.7549], dtype=float32),
#               (2, 5): array([1142.1879], dtype=float32),
#               (3, 1): array([986.90894], dtype=float32),
#               (3, 2): array([948.2113], dtype=float32),
#               (3, 4): array([1127.8575], dtype=float32),
#               (3, 5): array([548.9244], dtype=float32),
#               (4, 1): array([8721.805], dtype=float32),
#               (4, 2): array([2287.4355], dtype=float32),
#               (4, 3): array([7810.841], dtype=float32),
#               (4, 5): array([6973.6577], dtype=float32),
#               (5, 1): array([528.83307], dtype=float32),
#               (5, 2): array([858.09375], dtype=float32),
#               (5, 3): array([3280.1926], dtype=float32),
#               (5, 4): array([951.68994], dtype=float32),
#               (0, 0): array([5387.152], dtype=float32)},
#              (5, 8, 6): {(1, 2): array([466.7214], dtype=float32),
#               (1, 3): array([906.48346], dtype=float32),
#               (1, 4): array([1015.38306], dtype=float32),
#               (1, 5): array([552.37225], dtype=float32),
#               (2, 1): array([456.10645], dtype=float32),
#               (2, 3): array([1422.4974], dtype=float32),
#               (2, 4): array([497.2342], dtype=float32),
#               (2, 5): 0,
#               (3, 1): array([433.36685], dtype=float32),
#               (3, 2): array([475.4938], dtype=float32),
#               (3, 4): array([1001.4559], dtype=float32),
#               (3, 5): 0,
#               (4, 1): array([464.32245], dtype=float32),
#               (4, 2): 0,
#               (4, 3): array([585.2516], dtype=float32),
#               (4, 5): array([600.2449], dtype=float32),
#               (5, 1): 0,
#               (5, 2): array([991.6528], dtype=float32),
#               (5, 3): array([860.541], dtype=float32),
#               (5, 4): array([957.34656], dtype=float32),
#               (0, 0): array([945.0212], dtype=float32)},
#              (5, 7, 5): {(1, 2): array([1469.0544], dtype=float32),
#               (1, 3): array([1483.7021], dtype=float32),
#               (1, 4): array([1445.3049], dtype=float32),
#               (1, 5): array([974.4038], dtype=float32),
#               (2, 1): array([1498.8958], dtype=float32),
#               (2, 3): array([3317.1106], dtype=float32),
#               (2, 4): array([497.20566], dtype=float32),
#               (2, 5): array([992.85156], dtype=float32),
#               (3, 1): array([1373.3953], dtype=float32),
#               (3, 2): array([2960.1177], dtype=float32),
#               (3, 4): array([2045.22], dtype=float32),
#               (3, 5): array([1402.5972], dtype=float32),
#               (4, 1): array([1044.7574], dtype=float32),
#               (4, 2): array([519.04004], dtype=float32),
#               (4, 3): array([497.04028], dtype=float32),
#               (4, 5): 0,
#               (5, 1): array([2365.9424], dtype=float32),
#               (5, 2): array([512.24927], dtype=float32),
#               (5, 3): array([2758.033], dtype=float32),
#               (5, 4): array([2683.6743], dtype=float32),
#               (0, 0): array([6062.4033], dtype=float32)},
#              (5, 13, 4): {(1, 2): array([1457.6476], dtype=float32),
#               (1, 3): array([1822.3604], dtype=float32),
#               (1, 4): array([523.27527], dtype=float32),
#               (1, 5): array([2917.1316], dtype=float32),
#               (2, 1): array([1535.5125], dtype=float32),
#               (2, 3): array([1524.865], dtype=float32),
#               (2, 4): array([2403.2485], dtype=float32),
#               (2, 5): array([490.66772], dtype=float32),
#               (3, 1): array([2511.1338], dtype=float32),
#               (3, 2): array([1054.5114], dtype=float32),
#               (3, 4): array([4542.0166], dtype=float32),
#               (3, 5): array([524.38617], dtype=float32),
#               (4, 1): array([889.2106], dtype=float32),
#               (4, 2): array([1387.2332], dtype=float32),
#               (4, 3): array([566.4127], dtype=float32),
#               (4, 5): array([484.23618], dtype=float32),
#               (5, 1): array([2413.0168], dtype=float32),
#               (5, 2): array([1862.4714], dtype=float32),
#               (5, 3): array([1948.7803], dtype=float32),
#               (5, 4): array([3635.9053], dtype=float32),
#               (0, 0): array([571.4284], dtype=float32)},
#              (5, 22, 0): {(1, 2): array([1401.9714], dtype=float32),
#               (1, 3): array([1465.9666], dtype=float32),
#               (1, 4): array([1007.32605], dtype=float32),
#               (1, 5): array([1042.9402], dtype=float32),
#               (2, 1): array([1529.4841], dtype=float32),
#               (2, 3): array([5533.8096], dtype=float32),
#               (2, 4): array([1119.2308], dtype=float32),
#               (2, 5): array([1181.446], dtype=float32),
#               (3, 1): array([2768.7642], dtype=float32),
#               (3, 2): array([1007.2867], dtype=float32),
#               (3, 4): array([4418.249], dtype=float32),
#               (3, 5): array([2444.53], dtype=float32),
#               (4, 1): array([1974.6583], dtype=float32),
#               (4, 2): array([1618.8572], dtype=float32),
#               (4, 3): 0,
#               (4, 5): array([963.3851], dtype=float32),
#               (5, 1): array([2028.8257], dtype=float32),
#               (5, 2): array([1877.55], dtype=float32),
#               (5, 3): array([3665.1182], dtype=float32),
#               (5, 4): array([4509.5273], dtype=float32),
#               (0, 0): array([2895.1667], dtype=float32)},
#              (5, 7, 1): {(1, 2): array([602.0359], dtype=float32),
#               (1, 3): array([2152.9976], dtype=float32),
#               (1, 4): array([1459.7217], dtype=float32),
#               (1, 5): array([1375.226], dtype=float32),
#               (2, 1): array([891.96155], dtype=float32),
#               (2, 3): array([3813.7827], dtype=float32),
#               (2, 4): array([1822.0432], dtype=float32),
#               (2, 5): 0,
#               (3, 1): array([1844.5903], dtype=float32),
#               (3, 2): array([1409.2418], dtype=float32),
#               (3, 4): array([1431.5981], dtype=float32),
#               (3, 5): 0,
#               (4, 1): 0,
#               (4, 2): array([483.31534], dtype=float32),
#               (4, 3): 0,
#               (4, 5): array([946.771], dtype=float32),
#               (5, 1): array([2001.9486], dtype=float32),
#               (5, 2): array([2413.3604], dtype=float32),
#               (5, 3): array([2927.9958], dtype=float32),
#               (5, 4): array([2958.406], dtype=float32),
#               (0, 0): array([3854.7903], dtype=float32)},
#              (5, 9, 6): {(1, 2): array([1336.873], dtype=float32),
#               (1, 3): array([1571.2319], dtype=float32),
#               (1, 4): 0,
#               (1, 5): array([2575.1836], dtype=float32),
#               (2, 1): 0,
#               (2, 3): array([466.698], dtype=float32),
#               (2, 4): 0,
#               (2, 5): 0,
#               (3, 1): array([478.9376], dtype=float32),
#               (3, 2): array([531.04144], dtype=float32),
#               (3, 4): array([993.0924], dtype=float32),
#               (3, 5): array([1430.1565], dtype=float32),
#               (4, 1): 0,
#               (4, 2): 0,
#               (4, 3): array([560.69403], dtype=float32),
#               (4, 5): 0,
#               (5, 1): array([468.3172], dtype=float32),
#               (5, 2): array([2238.4976], dtype=float32),
#               (5, 3): array([2062.4973], dtype=float32),
#               (5, 4): array([1545.6731], dtype=float32),
#               (0, 0): array([1166.5259], dtype=float32)},
#              (5, 8, 2): {(1, 2): array([2025.0022], dtype=float32),
#               (1, 3): array([454.71255], dtype=float32),
#               (1, 4): 0,
#               (1, 5): 0,
#               (2, 1): array([1083.4077], dtype=float32),
#               (2, 3): array([1432.3743], dtype=float32),
#               (2, 4): array([1601.4926], dtype=float32),
#               (2, 5): 0,
#               (3, 1): array([931.61304], dtype=float32),
#               (3, 2): array([943.41895], dtype=float32),
#               (3, 4): 0,
#               (3, 5): 0,
#               (4, 1): 0,
#               (4, 2): array([578.2801], dtype=float32),
#               (4, 3): array([1112.1621], dtype=float32),
#               (4, 5): 0,
#               (5, 1): array([608.83624], dtype=float32),
#               (5, 2): array([649.4352], dtype=float32),
#               (5, 3): array([369.352], dtype=float32),
#               (5, 4): array([462.45258], dtype=float32),
#               (0, 0): array([506.111], dtype=float32)},
#              (3, 7, 1): {(1, 2): array([4415.5786], dtype=float32),
#               (1, 3): array([443.24704], dtype=float32),
#               (1, 4): array([432.1116], dtype=float32),
#               (1, 5): array([476.97668], dtype=float32),
#               (2, 1): array([960.3766], dtype=float32),
#               (2, 3): array([920.61365], dtype=float32),
#               (2, 4): array([883.3569], dtype=float32),
#               (2, 5): array([921.6559], dtype=float32),
#               (3, 1): array([10974.357], dtype=float32),
#               (3, 2): array([16449.357], dtype=float32),
#               (3, 4): array([8121.2705], dtype=float32),
#               (3, 5): array([10482.19], dtype=float32),
#               (4, 1): array([3896.1873], dtype=float32),
#               (4, 2): array([2777.1936], dtype=float32),
#               (4, 3): array([1358.4996], dtype=float32),
#               (4, 5): array([2485.9756], dtype=float32),
#               (5, 1): array([1806.8344], dtype=float32),
#               (5, 2): array([1972.8909], dtype=float32),
#               (5, 3): array([387.67105], dtype=float32),
#               (5, 4): array([2690.316], dtype=float32),
#               (0, 0): array([42377.14], dtype=float32)},
#              (2, 3, 2): {(1, 2): array([482.5902], dtype=float32),
#               (1, 3): array([1095.1852], dtype=float32),
#               (1, 4): array([902.43134], dtype=float32),
#               (1, 5): array([967.3567], dtype=float32),
#               (2, 1): array([1886.1711], dtype=float32),
#               (2, 3): array([2963.4463], dtype=float32),
#               (2, 4): array([1400.0693], dtype=float32),
#               (2, 5): array([2143.4912], dtype=float32),
#               (3, 1): array([564.3423], dtype=float32),
#               (3, 2): array([584.5318], dtype=float32),
#               (3, 4): 0,
#               (3, 5): array([1049.604], dtype=float32),
#               (4, 1): array([1282.4705], dtype=float32),
#               (4, 2): 0,
#               (4, 3): array([1149.4792], dtype=float32),
#               (4, 5): array([1455.2666], dtype=float32),
#               (5, 1): 0,
#               (5, 2): array([954.07007], dtype=float32),
#               (5, 3): array([1946.3109], dtype=float32),
#               (5, 4): array([2115.586], dtype=float32),
#               (0, 0): array([2389.5112], dtype=float32)}})

# %%
len(Q_dict)
# Out:
# 840

# %% [markdown]
# ### Tracking Convergence
#
# - Check for value convergence of the few tracked state-action pairs
# - Also check for how rewards improve over time

# %%
# Write the code for plotting the graphs for state-action pairs tracked
plt.figure(0, figsize=(20,20))

plt.subplot(321)
plt.title('State = (2,17,6), Action = (4,5)')
plt.plot(np.asarray(range(0, len(states_tracked[(2,17,6)][(4,5)]))),
         np.asarray(states_tracked[(2,17,6)][(4,5)]))

plt.subplot(322)
plt.title('State = (4,22,5), Action = (2,5)')
plt.plot(np.asarray(range(0, len(states_tracked[(4,22,5)][(2,5)]))), \
         np.asarray(states_tracked[(4,22,5)][(2,5)]))

plt.subplot(323)
plt.title('State = (2,4,1), Action = (0,0)')
plt.plot(np.asarray(range(0, len(states_tracked[(2,4,1)][(0,0)]))), \
         np.asarray(states_tracked[(2,4,1)][(0,0)]))

plt.subplot(324)
plt.title('State = (1,18,3), Action = (4,2)')
plt.plot(np.asarray(range(0, len(states_tracked[(1,18,3)][(4,2)]))), \
         np.asarray(states_tracked[(1,18,3)][(4,2)]))

plt.subplot(325)
plt.title('State = (3,12,6), Action = (1,4)')
plt.plot(np.asarray(range(0, len(states_tracked[(3,12,6)][(1,4)]))), \
         np.asarray(states_tracked[(3,12,6)][(1,4)]))

plt.subplot(326)
plt.title('State = (4,6,2), Action = (4,3)')
plt.plot(np.asarray(range(0, len(states_tracked[(4,6,2)][(4,3)]))), \
         np.asarray(states_tracked[(4,6,2)][(4,3)]))

plt.show()

# %% [markdown]
# - As seen above, the Q-values are converging well
# - Results obtained are very good
# - Experiment has taken lot of time to run 6.2 hours (22350 seconds)
# - Hence we stop the experiment now

# %%
# Plot the rewards per episode
plt.figure(0, figsize=(20,10))
plt.title('Reward per Episode')
plt.plot(np.asarray(range(0, len(total_rewards))), np.asarray(total_rewards))
#plt.plot(np.asarray(range(0, 100)), np.asarray(total_rewards[-101:-1]))
plt.show()

# %%
rewards_arr = np.array(total_rewards)
n = rewards_arr.size
rew_arr_new = rewards_arr[:(n // 100) * 100].reshape(100, -1) #converting the rewards to (100, 50000)
y = rew_arr_new.mean(axis = 1) #taking mean of every 50k records
plt.title("Model Improvement Plot - Q-Learning")
plt.plot(y)

# %% [markdown]
# #### Epsilon-decay sample function

# %% [markdown]
# <div class="alert alert-block alert-info">
# Try building a similar epsilon-decay function for your model.
# </div>

# %%
time = np.arange(0,100000)
epsilon = []
for i in range(0,100000):
    epsilon.append(0 + (1 - 0) * np.exp(-0.00005*i))

# %%
plt.plot(time, epsilon)
plt.show()

# %%
time = np.arange(0,1000)
epsilon = []
for i in range(0,1000):
    epsilon.append(0 + (1 - 0) * np.exp(-0.005*i))

# %%
plt.plot(time, epsilon)
plt.show()

# %%
0.00005
# Out:
# 5e-05

# %%
time = np.arange(0,50000)
epsilon = []
for i in range(0,50000):
    epsilon.append(0 + (1 - 0) * np.exp(-0.00005*i))

# %%
plt.plot(time, epsilon)
plt.show()
